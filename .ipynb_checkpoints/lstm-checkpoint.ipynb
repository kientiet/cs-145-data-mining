# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %load_ext autoreload
# %autoreload 2

# %%
data_dir = os.path.join(os.getcwd(), "ucla-covid19-prediction")

# %%
columns = ["Province_State", "Date", "Recovered","Active", "Incident_Rate", "Total_Test_Results", "Case_Fatality_Ratio", "Testing_Rate", "Confirmed", "Deaths"]

# %%
# Class dataset
dataset = pd.read_csv(os.path.join(data_dir, "train_trendency.csv"), index_col=0)
dataset = dataset.reindex(columns=columns)

dataset
# Out:
#      Province_State        Date  Recovered     Active  Incident_Rate  \
# 0           Alabama  01-12-2021   211684.0   190591.0    8318.021857
# 1            Alaska  01-12-2021     7165.0    43132.0    6906.205360
# 2           Arizona  01-12-2021    86757.0   538861.0    8739.177523
# 3          Arkansas  01-12-2021   229700.0    25732.0    8600.724235
# 4        California  01-12-2021        NaN  2773506.0    7098.216165
# ...             ...         ...        ...        ...            ...
# 3945       Virginia  03-31-2021        NaN        NaN    7251.767584
# 3946     Washington  03-31-2021        NaN        NaN    4786.488792
# 3947  West Virginia  03-31-2021        NaN        NaN    7908.837835
# 3948      Wisconsin  03-31-2021        NaN        NaN   10923.970972
# 3949        Wyoming  03-31-2021        NaN        NaN    9729.438333
#
#       Total_Test_Results  Case_Fatality_Ratio   Testing_Rate  Confirmed  \
# 0              1981019.0             1.366440   40402.697430     407848
# 1              1357708.0             0.445351  185594.597735      50544
# 2              5742443.0             1.647854   42806.225328     636100
# 3              2208736.0             1.587730   73190.174047     259553
# 4             36508384.0             1.110900   92397.696784    2832085
# ...                  ...                  ...            ...        ...
# 3945           6466133.0             1.656284   75755.592601     618976
# 3946           5890924.0             1.439561   77360.561731     364486
# 3947           2468123.0             1.887991  137718.780881     141738
# 3948           7585402.0             1.150083  130278.883367     636041
# 3949            683766.0             1.243118  118143.475955      56310
#
#       Deaths
# 0       5573
# 1        225
# 2      10482
# 3       4121
# 4      31345
# ...      ...
# 3945   10252
# 3946    5247
# 3947    2676
# 3948    7315
# 3949     700
#
# [3950 rows x 10 columns]

# %%
test_dataset = pd.read_csv(os.path.join(data_dir, "test_data.csv"), index_col=0)
test_dataset
# Out:
#      Province_State  Confirmed  Deaths  Recovered  Active  Incident_Rate  \
# 0           Alabama     515866   10553        NaN     NaN   10521.038876
# 1            Alaska      63298     313        NaN     NaN    8637.746140
# 2           Arizona     842192   16977        NaN     NaN   11570.610590
# 3          Arkansas     330609    5636        NaN     NaN   10955.284041
# 4        California    3671349   59411        NaN     NaN    9291.679185
# ...             ...        ...     ...        ...     ...            ...
# 1495       Virginia     659590   10770        NaN     NaN    7727.591023
# 1496     Washington     403040    5499        NaN     NaN    5292.786123
# 1497  West Virginia     153128    2679        NaN     NaN    8544.388379
# 1498      Wisconsin     660450    7550        NaN     NaN   11343.194272
# 1499        Wyoming      58142     707        NaN     NaN   10045.977687
#
#       Total_Test_Results  Case_Fatality_Ratio   Testing_Rate        Date
# 0              2406977.0             2.045686   49090.071046  04-01-2021
# 1              1904230.0             0.495339  260302.510440  04-01-2021
# 2              8533893.0             2.015811  117244.467672  04-01-2021
# 3              2857923.0             1.704733   94702.074754  04-01-2021
# 4             53786487.0             1.618234  136126.198215  04-01-2021
# ...                  ...                  ...            ...         ...
# 1495           7014294.0             1.632833   82177.709405  04-30-2021
# 1496           6508152.0             1.364381   85466.099130  04-30-2021
# 1497           2738468.0             1.749517  152803.759959  04-30-2021
# 1498           8255143.0             1.143160  141781.650080  04-30-2021
# 1499            724041.0             1.215988  125102.331022  04-30-2021
#
# [1500 rows x 10 columns]

# %%
dataset["Date"] = dataset["Date"].map(lambda date: date[:5])

# %%
dataset.isna().sum()
# Out:
# Province_State            0
# Date                      0
# Confirmed                 0
# Deaths                    0
# Recovered              1933
# Active                 1250
# Incident_Rate             0
# Total_Test_Results        0
# Case_Fatality_Ratio       0
# Testing_Rate              0
# dtype: int64

# %% [markdown]
# Group confirmed case by Date

# %% [markdown]
# # Pre-processing data

# %%
dataset["Date"] = dataset["Date"].map(lambda date: date[:5])

# %% [markdown]
# # LSTM Model

# %%
from lstm import LSTMTrainer

trainer = LSTMTrainer(dataset, val_dataset=None)
trainer.fit()
# Out:
# >> At epoch 0
# >> At epoch 1
# >> At epoch 2
# >> At epoch 3
# >> At epoch 4
# >> At epoch 5
# >> At epoch 6
# >> At epoch 7
# >> At epoch 8
# >> At epoch 9
# Final performance
# [  57976.42 3468557.5 ]

# %% [markdown]
# # Test on external testset

# %%
from model import learning_process_with_external_test
from sklearn.linear_model import LinearRegression
from utils import cumulative

result = learning_process_with_external_test(dataset, test_dataset, LinearRegression(), smooth_function=heuristic_smooth)

# %%
result[0]
